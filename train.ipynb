# %% [markdown]
# # Train JaxMarl Models in Google Colab
# Ensure you are using a GPU runtime (`Runtime` -> `Change runtime type` -> `T4 GPU` or similar).

# %%
# Mount Google Drive if your repository is stored there
# from google.colab import drive
# drive.mount('/content/drive')

# cd into the folder containing your code
# %cd /content/drive/MyDrive/OpenEndedness

# %%
# Install dependencies
# !pip install jax[cuda12] flax optax wandb
# !pip install git+https://github.com/FLAIROx/JaxMARL.git
# !pip install navix

# %%
import sys
import os

# Add the v2_JaxMarl directory to the Python path so local imports work
sys.path.append(os.path.abspath('./v2_JaxMarl'))

# %%
import wandb

# You may need to log in to wandb
wandb.login()

# %%
from train import main

# Start the training loop
main()
